# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav-Karthick/Spam-Message-Detection-/blob/main/Spam_Message_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/content/spam.csv', encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'message']
df['label_num'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
X = df['message']
y = df['label_num']

X_train, X_test, y_train, _ = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X_train_tfidf = vectorizer.fit_transform(X_train)

# %%
X_train, X_test, y_train, _ = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression()

# %%
raw_scores = model.decision_function(sample_tfidf)
sigmoid_scores = sigmoid(raw_scores)

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
sample_df['sigmoid_prob_spam'] = sigmoid_scores
sample_df['predicted_label'] = np.where(
    sample_df['sigmoid_prob_spam'] > 0.5,
    'spam',
    'not spam'
)

# %%
sample_df[['message', 'sigmoid_prob_spam', 'predicted_label']]
# Out:
#                                                 message  sigmoid_prob_spam  \
# 3245  Funny fact Nobody teaches volcanoes 2 erupt, t...           0.085893
# 944   I sent my scores to sophas and i had to do sec...           0.104360
# 1044  We know someone who you know that fancies you....           0.220430
# 2484  Only if you promise your getting out as SOON a...           0.034934
# 812   Congratulations ur awarded either å£500 of CD ...           0.903440
# 2973         I'll text carlos and let you know, hang on           0.080986
# 2991          K.i did't see you.:)k:)where are you now?           0.032409
# 2942             No message..no responce..what happend?           0.112828
# 230   Get down in gandhipuram and walk to cross cut ...           0.026454
# 1181                         You flippin your shit yet?           0.063693
#
#      predicted_label
# 3245        not spam
# 944         not spam
# 1044        not spam
# 2484        not spam
# 812             spam
# ...
